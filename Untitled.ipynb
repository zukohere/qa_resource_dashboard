# %%
import pandas as pd

# %%
# Topic/Employee Admin Parameters/sheet columns
adminList = ["TopicGoals", "EmpRoster", "EmpAffinity"]

adminCols = {"TopicGoals": ["Topic","Goal","std_hours"], 
             "EmpRoster": ["EmpNum","Last","First","Title","Department"], 
             "EmpAffinity": ["EmpNum","Last","First","Title","Topic","SkillRating_1to5"]}

# Timesheet parameters/sheet columns
TopicList = ["CAPA",
"Inspection",
"New Product",
"Audit",
"Training"
]

TopicCols = {
    "CAPA": ["IssueNum","TaskType","EmpNum","Hours","Date","Status","Product"],
"Inspection": ["InspectionNum","Product","InspType","EmpNum","Hours","Date","Status"],
"New Product": ["ProjectNum", "Product","TaskType","EmpNum","Hours","Date","Status"],
"Audit": ["AuditNo","Lead","Duration","TargetDate","ActualDate","Type","Title"],
"Training": ["Instructor","Duration","TargetDate","ActualDate","Type","DocNo","DocName","RefNum"]
}

sheets = adminList + TopicList
colLookups = {**adminCols, **TopicCols}

# desiredCols = [Topic, RefNum, Detail, SubType, Date, Hours, Status, EmpNum, EmpName]
renameDict ={
        "CAPA": {"IssueNum":"RefNum",
                 "Product": "Detail",
                 "TaskType": "SubType",
                 "EmpNum": "EmpNum",
                 "Hours": "Hours",
                 "Date": "Date",
                 "Status": "Status"},
"Inspection": {"InspectionNum": "RefNum",
               "Product": "Detail",
               "InspType": "SubType",
               "EmpNum": "EmpNum",
               "Hours": "Hours",
               "Date": "Date",
               "Status": "Status"},
"New Product": {"ProjectNum":"RefNum",
                "Product": "Detail",
                "TaskType": "SubType",
                "EmpNum": "EmpNum",
                "Hours": "Hours",
                "Date": "Date",
                "Status": "Status"},
"Audit": {"AuditNo": "RefNum",
          "Lead": "EmpNum",
          "Duration": "Hours",
#           "TargetDate",
          "ActualDate": "Date",
          "Type": "SubType",
         "Title": "Detail"},
"Training": {"Instructor": "EmpNum",
             "Duration": "Hours",
#              "TargetDate",
             "ActualDate": "Date",
             "Type": "SubType",
             "DocNo": "Detail",
#              "DocName"
             "RefNum": "RefNum"
            }
}

# %%
xlsx = pd.ExcelFile('TimeSheetGenerator.xlsx')

# %%
# QUALITY CHECK: Are expected sheets and columns present?
sheetCheck = {}
for sheet in sheets:
    if sheet in xlsx.sheet_names:
        sheetCheck[sheet] = sheet + " is present."
    else:
        sheetCheck[sheet] = "Error: "+ sheet + " NOT is present."

# %%
sheetCheck
# Out:
# {'TopicGoals': 'TopicGoals is present.',
#  'EmpRoster': 'EmpRoster is present.',
#  'EmpAffinity': 'EmpAffinity is present.',
#  'CAPA': 'CAPA is present.',
#  'Inspection': 'Inspection is present.',
#  'New Product': 'New Product is present.',
#  'Audit': 'Audit is present.',
#  'Training': 'Training is present.'}

# %%
colCheck = {}
for sheet in sheets:
    checksheet = xlsx.parse(sheet_name=sheet)
    for col in colLookups[sheet]:
        if col not in checksheet.columns:
            colCheck[sheet] = "Error: Column "+ col + " is NOT present."
        else:
            colCheck[sheet] = "All columns present."

# %%
colCheck
# Out:
# {'TopicGoals': 'All columns present.',
#  'EmpRoster': 'All columns present.',
#  'EmpAffinity': 'All columns present.',
#  'CAPA': 'All columns present.',
#  'Inspection': 'All columns present.',
#  'New Product': 'All columns present.',
#  'Audit': 'All columns present.',
#  'Training': 'All columns present.'}

# %%
# Create dictionary of dataframes with only needed columns from colLookups
dfDict = {}
for sheet in sheets:
    dfDict[sheet]=pd.read_excel(xlsx,sheet)[colLookups[sheet]]

# %%
# Add Status to Audit and Training for On-time/Late
for topic in ["Audit","Training"]:
    StatusList = []
    for index, row in dfDict[topic].iterrows():
        if row["ActualDate"] > row["TargetDate"]:
            StatusList.append("Late")
        else:
            StatusList.append("On Time")
    dfDict[topic]["Status"] = StatusList

# %%
# Standardize column names
for topic in TopicList:
#     print(topic)
    dfDict[topic]=dfDict[topic].rename(columns = renameDict[topic])
    dfDict[topic]["Topic"] = topic
    dfDict[topic] = dfDict[topic][["Topic", "RefNum", "Detail", "SubType", 
                                  "Date", "Hours", "Status", "EmpNum"]]

# %%
# combine all dfs
fulldf = pd.concat([dfDict[topic] for topic in TopicList])

# %%
dfDict["EmpRoster"]["EmpName"] = dfDict["EmpRoster"]["First"].str[0]+" "+dfDict["EmpRoster"]["Last"]
namejoin = dfDict["EmpRoster"][["EmpNum","Title","EmpName"]]
namejoin
# Out:
#    EmpNum                Title     EmpName
# 0   32301   Quality Supervisor     J Scott
# 1   49570            Inspector    Z Taylor
# 2   77030      Quality Analyst  B Cranston
# 3   77707  Quality Coordinator      T Kwan
# 4   29436            Inspector      K Hart
# 5   88927     Quality Engineer    T Oliver

# %%
finaldf = fulldf.merge(namejoin, how='inner', on='EmpNum')

# %%
finaldf = finaldf.groupby(["EmpNum","EmpName","Title","Topic","Status"])["Hours"].agg(['sum','count'])
# Out:
#                                                               sum  count
# EmpNum  EmpName    Title               Topic       Status
# 29436.0 K Hart     Inspector           CAPA        Late      8.00      3
#                                                    On Time   3.00      1
#                                        Inspection  Late      3.50      3
#                                                    On Time   4.00      3
#                                        New Product Late     16.50      4
#                                                    On Time   8.50      3
#                                        Training    On Time   6.00      7
# 32301.0 J Scott    Quality Supervisor  Audit       On Time  10.50      4
#                                        CAPA        Late      3.00      1
#                                                    On Time   5.00      2
#                                        Inspection  Late      2.75      2
#                                                    On Time   1.00      1
#                                        New Product On Time   5.50      2
#                                        Training    On Time   6.25      5
# 49570.0 Z Taylor   Inspector           Audit       Late      5.00      2
#                                                    On Time  15.50      5
#                                        CAPA        Late      8.00      2
#                                                    On Time  13.00      3
#                                        Inspection  Late      5.75      4
#                                                    On Time   1.00      2
#                                        New Product Late      4.00      2
#                                                    On Time   2.50      2
#                                        Training    Late      0.75      1
#                                                    On Time   1.25      2
# 77030.0 B Cranston Quality Analyst     Audit       Late      3.50      2
#                                                    On Time  44.00     13
#                                        CAPA        Late     27.00      7
#                                                    On Time   8.00      2
#                                        Inspection  Late      1.00      2
#                                                    On Time   5.25      6
#                                        New Product Late     11.00      3
#                                                    On Time   6.50      2
#                                        Training    Late      0.50      1
#                                                    On Time   1.75      3
# 77707.0 T Kwan     Quality Coordinator Audit       Late      8.00      2
#                                                    On Time   9.50      6
#                                        CAPA        Late      6.00      2
#                                                    On Time   3.00      1
#                                        Inspection  Late      3.25      2
#                                                    On Time   2.50      2
#                                        New Product Late     16.50      4
#                                                    On Time   2.00      1
#                                        Training    On Time   7.50      8
# 88927.0 T Oliver   Quality Engineer    CAPA        Late     14.00      4
#                                                    On Time  13.00      5
#                                        Inspection  Late      6.00      5
#                                                    On Time   6.25      3
#                                        New Product Late      9.00      3
#                                        Training    Late      0.75      1
#                                                    On Time   4.25      5

# %%
finaldf.to_dict(orient = "records")
# Out:
# [{'Topic': 'CAPA',
#   'RefNum': 'NC304',
#   'Detail': 'PQR',
#   'SubType': 'Root Cause Analysis',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC305',
#   'Detail': 'MNO',
#   'SubType': 'Verification',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC400',
#   'Detail': 'YZ1',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC300',
#   'Detail': 'YZ1',
#   'SubType': 'Root Cause Analysis',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC324',
#   'Detail': 'JKL',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 6.0,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC369',
#   'Detail': 'STU',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC374',
#   'Detail': 'DEF',
#   'SubType': 'Root Cause Analysis',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC343',
#   'Detail': 'MNO',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC346',
#   'Detail': 'ABC',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Inspection',
#   'RefNum': 6064,
#   'Detail': 'STU',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 2.25,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Inspection',
#   'RefNum': 6097,
#   'Detail': 'PQR',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Inspection',
#   'RefNum': 7566,
#   'Detail': 'JKL',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Inspection',
#   'RefNum': 7276,
#   'Detail': 'DEF',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Inspection',
#   'RefNum': 7267,
#   'Detail': 'YZ1',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Inspection',
#   'RefNum': 6265,
#   'Detail': 'MNO',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Inspection',
#   'RefNum': 6856,
#   'Detail': 'ABC',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Inspection',
#   'RefNum': 6931,
#   'Detail': 'MNO',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'New Product',
#   'RefNum': 6652.0,
#   'Detail': 'NP2',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'New Product',
#   'RefNum': 6258.0,
#   'Detail': 'NP1',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'New Product',
#   'RefNum': 6275.0,
#   'Detail': 'NP4',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 5.5,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Training',
#   'RefNum': 96966,
#   'Detail': 'CAPA-002',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Training',
#   'RefNum': 99302,
#   'Detail': 'INSP-001',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Training',
#   'RefNum': 97842,
#   'Detail': 'CAPA-002',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Training',
#   'RefNum': 87513,
#   'Detail': 'CAPA-002',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Training',
#   'RefNum': 98290,
#   'Detail': 'AUDI-021',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'Late',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'Training',
#   'RefNum': 93478,
#   'Detail': 'CAPA-002',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 88927.0,
#   'Title': 'Quality Engineer',
#   'EmpName': 'T Oliver'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC381',
#   'Detail': 'DEF',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC348',
#   'Detail': 'VWX',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 6.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC367',
#   'Detail': 'JKL',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC327',
#   'Detail': 'DEF',
#   'SubType': 'Verification',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC327',
#   'Detail': 'GHI',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC318',
#   'Detail': 'VWX',
#   'SubType': 'Verification',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC350',
#   'Detail': 'VWX',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC334',
#   'Detail': 'DEF',
#   'SubType': 'Verification',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC345',
#   'Detail': 'MNO',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 6.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Inspection',
#   'RefNum': 7584,
#   'Detail': 'GHI',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Inspection',
#   'RefNum': 7901,
#   'Detail': 'ABC',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Inspection',
#   'RefNum': 6987,
#   'Detail': 'GHI',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Inspection',
#   'RefNum': 6179,
#   'Detail': 'JKL',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Inspection',
#   'RefNum': 7844,
#   'Detail': 'MNO',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Inspection',
#   'RefNum': 6545,
#   'Detail': 'STU',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Inspection',
#   'RefNum': 6044,
#   'Detail': 'PQR',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Inspection',
#   'RefNum': 6933,
#   'Detail': 'JKL',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'New Product',
#   'RefNum': 6562.0,
#   'Detail': 'NP4',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'New Product',
#   'RefNum': 6948.0,
#   'Detail': 'NP4',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'New Product',
#   'RefNum': 7563.0,
#   'Detail': 'NP2',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 4.5,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'New Product',
#   'RefNum': 7075.0,
#   'Detail': 'NP4',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'New Product',
#   'RefNum': 6469.0,
#   'Detail': 'NP4',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 4.5,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 202,
#   'Detail': 'QMS',
#   'SubType': 'System',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 8.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 221,
#   'Detail': 'Finished Good',
#   'SubType': 'Product',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 217,
#   'Detail': 'In Process',
#   'SubType': 'Product',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 225,
#   'Detail': 'Vendor B',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 2.5,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 208,
#   'Detail': 'Purchased',
#   'SubType': 'Product',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 207,
#   'Detail': 'Engineering',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 222,
#   'Detail': 'Purchasing',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 230,
#   'Detail': 'Inspection',
#   'SubType': 'Equipment Control',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 218,
#   'Detail': 'Vendor A',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 213,
#   'Detail': 'Vendor A',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 211,
#   'Detail': 'Inspection',
#   'SubType': 'Equipment Control',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 226,
#   'Detail': 'Vendor A',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 222,
#   'Detail': 'Purchasing',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 2.5,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 212,
#   'Detail': 'Engineering',
#   'SubType': 'Equipment Control',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Audit',
#   'RefNum': 221,
#   'Detail': 'Purchasing',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 5.5,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Training',
#   'RefNum': 87352,
#   'Detail': 'CAPA-002',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Training',
#   'RefNum': 82946,
#   'Detail': 'AUDI-028',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Training',
#   'RefNum': 97873,
#   'Detail': 'AUDI-028',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'Training',
#   'RefNum': 98558,
#   'Detail': 'AUDI-028',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'Late',
#   'EmpNum': 77030.0,
#   'Title': 'Quality Analyst',
#   'EmpName': 'B Cranston'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC310',
#   'Detail': 'GHI',
#   'SubType': 'Root Cause Analysis',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC321',
#   'Detail': 'YZ1',
#   'SubType': 'Root Cause Analysis',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 6.0,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC315',
#   'Detail': 'STU',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 6.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC351',
#   'Detail': 'DEF',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC337',
#   'Detail': 'JKL',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Inspection',
#   'RefNum': 6073,
#   'Detail': 'GHI',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Inspection',
#   'RefNum': 6373,
#   'Detail': 'GHI',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Inspection',
#   'RefNum': 6713,
#   'Detail': 'VWX',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Inspection',
#   'RefNum': 7845,
#   'Detail': 'ABC',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Inspection',
#   'RefNum': 7425,
#   'Detail': 'JKL',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Inspection',
#   'RefNum': 6186,
#   'Detail': 'YZ1',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'New Product',
#   'RefNum': 7789.0,
#   'Detail': 'NP2',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'New Product',
#   'RefNum': 7927.0,
#   'Detail': 'NP3',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 2.5,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'New Product',
#   'RefNum': 7031.0,
#   'Detail': 'NP1',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'New Product',
#   'RefNum': 6560.0,
#   'Detail': 'NP4',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Audit',
#   'RefNum': 206,
#   'Detail': 'Vendor B',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Audit',
#   'RefNum': 218,
#   'Detail': 'Manufacturing',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Audit',
#   'RefNum': 212,
#   'Detail': 'Manufacturing',
#   'SubType': 'Equipment Control',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Audit',
#   'RefNum': 210,
#   'Detail': 'Vendor C',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Audit',
#   'RefNum': 219,
#   'Detail': 'Purchasing',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Audit',
#   'RefNum': 218,
#   'Detail': 'Engineering',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Audit',
#   'RefNum': 203,
#   'Detail': 'Finished Good',
#   'SubType': 'Product',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Training',
#   'RefNum': 89102,
#   'Detail': 'INSP-001',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'Late',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Training',
#   'RefNum': 96479,
#   'Detail': 'INSP-001',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'Training',
#   'RefNum': 95940,
#   'Detail': 'INSP-001',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 49570.0,
#   'Title': 'Inspector',
#   'EmpName': 'Z Taylor'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC371',
#   'Detail': 'JKL',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC399',
#   'Detail': 'DEF',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC308',
#   'Detail': 'ABC',
#   'SubType': 'Root Cause Analysis',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Inspection',
#   'RefNum': 6063,
#   'Detail': 'PQR',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Inspection',
#   'RefNum': 7806,
#   'Detail': 'YZ1',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Inspection',
#   'RefNum': 7961,
#   'Detail': 'STU',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Inspection',
#   'RefNum': 6293,
#   'Detail': 'VWX',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'New Product',
#   'RefNum': 7701.0,
#   'Detail': 'NP3',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'New Product',
#   'RefNum': 7902.0,
#   'Detail': 'NP2',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'New Product',
#   'RefNum': 7522.0,
#   'Detail': 'NP1',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'New Product',
#   'RefNum': 6099.0,
#   'Detail': 'NP3',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'New Product',
#   'RefNum': 6882.0,
#   'Detail': 'NP4',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 5.5,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Audit',
#   'RefNum': 205,
#   'Detail': 'Purchasing',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 3.5,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Audit',
#   'RefNum': 223,
#   'Detail': 'Engineering',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Audit',
#   'RefNum': 215,
#   'Detail': 'Engineering',
#   'SubType': 'Equipment Control',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Audit',
#   'RefNum': 222,
#   'Detail': 'Vendor C',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 5.0,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Audit',
#   'RefNum': 219,
#   'Detail': 'Inspection',
#   'SubType': 'Equipment Control',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Audit',
#   'RefNum': 200,
#   'Detail': 'Vendor C',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'Late',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Audit',
#   'RefNum': 213,
#   'Detail': 'Engineering',
#   'SubType': 'Equipment Control',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Audit',
#   'RefNum': 212,
#   'Detail': 'Manufacturing',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Training',
#   'RefNum': 82380,
#   'Detail': 'INSP-001',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Training',
#   'RefNum': 96183,
#   'Detail': 'AUDI-028',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Training',
#   'RefNum': 90547,
#   'Detail': 'AUDI-028',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Training',
#   'RefNum': 82444,
#   'Detail': 'INSP-001',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Training',
#   'RefNum': 93543,
#   'Detail': 'AUDI-028',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Training',
#   'RefNum': 95947,
#   'Detail': 'AUDI-028',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Training',
#   'RefNum': 92150,
#   'Detail': 'INSP-001',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'Training',
#   'RefNum': 93125,
#   'Detail': 'AUDI-028',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 77707.0,
#   'Title': 'Quality Coordinator',
#   'EmpName': 'T Kwan'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC398',
#   'Detail': 'STU',
#   'SubType': 'Root Cause Analysis',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC381',
#   'Detail': 'ABC',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC333',
#   'Detail': 'GHI',
#   'SubType': 'Risk Analysis',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC382',
#   'Detail': 'PQR',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Inspection',
#   'RefNum': 6010,
#   'Detail': 'DEF',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Inspection',
#   'RefNum': 7683,
#   'Detail': 'GHI',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 2.25,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Inspection',
#   'RefNum': 7115,
#   'Detail': 'JKL',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Inspection',
#   'RefNum': 6841,
#   'Detail': 'JKL',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.75,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Inspection',
#   'RefNum': 7607,
#   'Detail': 'DEF',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Inspection',
#   'RefNum': 6507,
#   'Detail': 'ABC',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'New Product',
#   'RefNum': 6857.0,
#   'Detail': 'NP2',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 4.5,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'New Product',
#   'RefNum': 6815.0,
#   'Detail': 'NP3',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 5.5,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'New Product',
#   'RefNum': 6415.0,
#   'Detail': 'NP2',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'New Product',
#   'RefNum': 6599.0,
#   'Detail': 'NP1',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 5.5,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'New Product',
#   'RefNum': 7141.0,
#   'Detail': 'NP3',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'New Product',
#   'RefNum': 6492.0,
#   'Detail': 'NP3',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'Late',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'New Product',
#   'RefNum': 6321.0,
#   'Detail': 'NP3',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Training',
#   'RefNum': 81198,
#   'Detail': 'INSP-001',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Training',
#   'RefNum': 89916,
#   'Detail': 'INSP-001',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Training',
#   'RefNum': 96477,
#   'Detail': 'AUDI-021',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Training',
#   'RefNum': 87006,
#   'Detail': 'AUDI-021',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 0.25,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Training',
#   'RefNum': 88547,
#   'Detail': 'INSP-001',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Training',
#   'RefNum': 84785,
#   'Detail': 'AUDI-021',
#   'SubType': 'In-Process',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'Training',
#   'RefNum': 88283,
#   'Detail': 'AUDI-021',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 29436.0,
#   'Title': 'Inspector',
#   'EmpName': 'K Hart'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC370',
#   'Detail': 'ABC',
#   'SubType': 'Planning & Implementation',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 3.0,
#   'Status': 'Late',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC326',
#   'Detail': 'DEF',
#   'SubType': 'Root Cause Analysis',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'CAPA',
#   'RefNum': 'NC384',
#   'Detail': 'GHI',
#   'SubType': 'Verification',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Inspection',
#   'RefNum': 6240,
#   'Detail': 'MNO',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 2.0,
#   'Status': 'Late',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Inspection',
#   'RefNum': 7632,
#   'Detail': 'DEF',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 0.75,
#   'Status': 'Late',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Inspection',
#   'RefNum': 6842,
#   'Detail': 'ABC',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'New Product',
#   'RefNum': 6070.0,
#   'Detail': 'NP4',
#   'SubType': 'Quality Planning',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'New Product',
#   'RefNum': 6354.0,
#   'Detail': 'NP3',
#   'SubType': 'Verification & Validation',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Audit',
#   'RefNum': 203,
#   'Detail': 'Engineering',
#   'SubType': 'Process',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Audit',
#   'RefNum': 203,
#   'Detail': 'Vendor C',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 4.0,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Audit',
#   'RefNum': 204,
#   'Detail': 'Purchased',
#   'SubType': 'Product',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 0.5,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Audit',
#   'RefNum': 219,
#   'Detail': 'Vendor C',
#   'SubType': 'Supplier',
#   'Date': Timestamp('2022-01-27 00:00:00'),
#   'Hours': 4.5,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Training',
#   'RefNum': 95705,
#   'Detail': 'AUDI-028',
#   'SubType': 'Raw Material',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 1.0,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Training',
#   'RefNum': 96164,
#   'Detail': 'INSP-001',
#   'SubType': 'Finished Good',
#   'Date': Timestamp('2022-01-26 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Training',
#   'RefNum': 97337,
#   'Detail': 'AUDI-028',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-25 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Training',
#   'RefNum': 99544,
#   'Detail': 'AUDI-028',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-24 00:00:00'),
#   'Hours': 1.5,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'},
#  {'Topic': 'Training',
#   'RefNum': 97907,
#   'Detail': 'AUDI-028',
#   'SubType': 'Returns',
#   'Date': Timestamp('2022-01-28 00:00:00'),
#   'Hours': 1.25,
#   'Status': 'On Time',
#   'EmpNum': 32301.0,
#   'Title': 'Quality Supervisor',
#   'EmpName': 'J Scott'}]
